# %% [markdown]
# # Spotify Dataset Capstone Project

# %% [markdown]
# **Introduction** - Spotify Datset contains information regarding Audio Features of 160000+ songs released in between 1921 and 2020
#
# Dataset is taken from [Kaggle Website](https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks)
#
# For this project, I was interestested in Analysing Spotify Dataset and understand few findings from the Dataset:
#
# There's a few questions we want to answer with our data here:
#
# **1) Which Attributes/features will likely lead a song to be more popular?**
#
# **2) What are the most Popular Tracks?**
#
# **3) Build a Song Recommendation System**

# %% [markdown]
# ## 1.Import Necessary Libraries

# %%
# %pip install tqdm
# %pip install distutils
# Out:
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.67.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement distutils (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# ERROR: No matching distribution found for distutils
# Note: you may need to restart the kernel to use updated packages.

# %%
# General tools
import os
import datetime

#For data Handling
import pandas as pd
import numpy as np

#For Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 
# %matplotlib inline

#Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

#Progreebar
from tqdm import tqdm

# For transformations and predictions
from scipy.optimize import curve_fit
# from yellowbrick.target import FeatureCorrelation
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# For scoring
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score,mean_absolute_error

# For validation
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2.Load Datasets

# %%
#Load all 5 Datasets

df = pd.read_csv('data/data.csv')

df_artist = pd.read_csv('data/data_by_artist.csv')

df_by_genres = pd.read_csv('data/data_by_genres.csv')

df_year = pd.read_csv('data/data_by_year.csv')

df_w_genres = pd.read_csv('data/data_w_genres.csv')

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
df_artist.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# 4  270436.142857  0.488286          0.009400  0.195000 -10.236714
#
#    speechiness       tempo   valence  popularity  key
# 0     0.210389  117.518111  0.389500   38.333333    5
# 1     0.176212  103.044154  0.268865   30.576923    5
# 2     0.118514   77.375857  0.354857   34.857143    0
# 3     0.123200   88.667630  0.372030   34.851852    0
# 4     0.098543  122.835857  0.482286   43.000000    5

# %%
df_by_genres.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# 1  0.221750   52.500000    5
# 2  0.975000   48.000000    7
# 3  0.513604   20.859882    7
# 4  0.448249   45.820071    7

# %%
df_year.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# 4    2.604317    5

# %%
df_w_genres.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# 0  0.290833 -14.448000     0.210389  117.518111  0.389500   38.333333    5
# 1  0.315215 -10.690000     0.176212  103.044154  0.268865   30.576923    5
# 2  0.325786 -15.230714     0.118514   77.375857  0.354857   34.857143    0
# 3  0.275481 -15.639370     0.123200   88.667630  0.372030   34.851852    0
# 4  0.195000 -10.236714     0.098543  122.835857  0.482286   43.000000    5
#
#    mode  count
# 0     1      9
# 1     1     26
# 2     1      7
# 3     1     27
# 4     1      7

# %% [markdown]
# ### 3. Exploratory Data Ananlysis

# %%
df.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# **Observation** - There are no nulls in the dataset. Perfect!

# %% [markdown]
# ## Data Cleaning

# %%
#Convert Milli secs duration into minutes
df['duration_min'] = df['duration_ms']/60000
df['duration_min'] = df['duration_min'].round(2)
df_by_genres['duration_min'] = df_by_genres['duration_ms']/60000
df_by_genres['duration_min'] = df_by_genres['duration_min'].round(2)

df['duration_min'].head()
# Out:
# 0    13.86
# 1     3.01
# 2     8.33
# 3     3.50
# 4     2.78
# Name: duration_min, dtype: float64

# %%
#Remove the Square Brackets from the artists

df["artists"]=df["artists"].str.replace("[", "")
df["artists"]=df["artists"].str.replace("]", "")
df["artists"]=df["artists"].str.replace("'", "")

df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  Sergei Rachmaninoff, James Levine, Berliner Ph...         0.279
# 1                                         Dennis Day         0.819
# 2  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.328
# 3                                       Frank Parker         0.275
# 4                                         Phil Regan         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo  duration_min
# 0       0.0366   80.954         13.86
# 1       0.4150   60.936          3.01
# 2       0.0339  110.339          8.33
# 3       0.0354  100.109          3.50
# 4       0.0380  101.665          2.78

# %%
#Add Song decade column in the dataset
df['Song Decade'] = None

df.loc[(df['year'] >= 1920) & (df['year'] < 1930), 'Song Decade'] = '1920s'
df.loc[(df['year'] >= 1930) & (df['year'] < 1940), 'Song Decade'] = '1930s'
df.loc[(df['year'] >= 1940) & (df['year'] < 1950), 'Song Decade'] = '1940s'
df.loc[(df['year'] >= 1950) & (df['year'] < 1960), 'Song Decade'] = '1950s'
df.loc[(df['year'] >= 1960) & (df['year'] < 1970), 'Song Decade'] = '1960s'
df.loc[(df['year'] >= 1970) & (df['year'] < 1980) , 'Song Decade'] = '1970s'
df.loc[(df['year'] >= 1980) & (df['year'] < 1990) , 'Song Decade'] = '1980s'
df.loc[(df['year'] >= 1990) & (df['year'] < 2000) , 'Song Decade'] = '1990s'
df.loc[(df['year'] >= 2000) & (df['year'] < 2010) , 'Song Decade'] = '2000s'
df.loc[(df['year'] >= 2010) & (df['year'] < 2020) , 'Song Decade'] = '2010s'
df.loc[(df['year'] >= 2020) & (df['year'] < 2030) , 'Song Decade'] = '2020s'

df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  Sergei Rachmaninoff, James Levine, Berliner Ph...         0.279
# 1                                         Dennis Day         0.819
# 2  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.328
# 3                                       Frank Parker         0.275
# 4                                         Phil Regan         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    ...  liveness  loudness  mode  \
# 0  ...     0.665   -20.096     1
# 1  ...     0.160   -12.441     1
# 2  ...     0.101   -14.850     1
# 3  ...     0.381    -9.316     1
# 4  ...     0.229   -10.096     1
#
#                                                 name popularity  release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...          4          1921
# 1                            Clancy Lowered the Boom          5          1921
# 2                                          Gati Bali          5          1921
# 3                                          Danny Boy          3          1921
# 4                        When Irish Eyes Are Smiling          2          1921
#
#   speechiness    tempo  duration_min  Song Decade
# 0      0.0366   80.954         13.86        1920s
# 1      0.4150   60.936          3.01        1920s
# 2      0.0339  110.339          8.33        1920s
# 3      0.0354  100.109          3.50        1920s
# 4      0.0380  101.665          2.78        1920s
#
# [5 rows x 21 columns]

# %%
#Remove unnecessary Braces from the genres column

df_w_genres['genres'] = df_w_genres['genres'].str.replace("'","")
df_w_genres['genres'] = df_w_genres['genres'].str.replace("[","")
df_w_genres['genres'] = df_w_genres['genres'].str.replace("]","")

df_w_genres.head()
# Out:
#        genres                                            artists  \
# 0  show tunes                   "Cats" 1981 Original London Cast
# 1                                      "Cats" 1983 Broadway Cast
# 2                    "Fiddler On The Roof” Motion Picture Chorus
# 3                 "Fiddler On The Roof” Motion Picture Orchestra
# 4              "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# 0  0.290833 -14.448000     0.210389  117.518111  0.389500   38.333333    5
# 1  0.315215 -10.690000     0.176212  103.044154  0.268865   30.576923    5
# 2  0.325786 -15.230714     0.118514   77.375857  0.354857   34.857143    0
# 3  0.275481 -15.639370     0.123200   88.667630  0.372030   34.851852    0
# 4  0.195000 -10.236714     0.098543  122.835857  0.482286   43.000000    5
#
#    mode  count
# 0     1      9
# 1     1     26
# 2     1      7
# 3     1     27
# 4     1      7

# %% [markdown]
# ### Drop Duplicates

# %%
df.duplicated().any().sum()
# Out:
# np.int64(0)

# %%
df[(df['artists'] == "Billie Holiday") & (df['name']== "No Regrets - Take 1")]
# Out:
#       valence  year  acousticness         artists  danceability  duration_ms  \
# 2293     0.77  1933          0.93  Billie Holiday         0.721       155667
# 2298     0.77  1933          0.93  Billie Holiday         0.721       155667
#
#       energy  explicit                      id  instrumentalness  ...  \
# 2293   0.186         0  65YsrE85spoEzDa3O8iCPT          0.000145  ...
# 2298   0.186         0  4FU5KzT1MaIuIV4thAY870          0.000145  ...
#
#       liveness  loudness  mode                 name popularity  release_date  \
# 2293     0.351   -13.833     1  No Regrets - Take 1         17          1933
# 2298     0.351   -13.833     1  No Regrets - Take 1         17          1933
#
#      speechiness    tempo  duration_min  Song Decade
# 2293      0.0458  129.452          2.59        1930s
# 2298      0.0458  129.452          2.59        1930s
#
# [2 rows x 21 columns]

# %% [markdown]
# **Observation** - There are not any duplicates in the data set because of the unique id feature.Let's see if we remove this are there any duplicates

# %%
df = df.drop(labels=['id', 'release_date'], axis=1)
df.shape
# Out:
# (170653, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(565)

# %% [markdown]
# **Observation** - After the Unique features removal, there are 628  duplicates found in the dataset which needs to be removed

# %%
df = df[~df.duplicated()==1]
df.shape
# Out:
# (170088, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  Sergei Rachmaninoff, James Levine, Berliner Ph...         0.279
# 1                                         Dennis Day         0.819
# 2  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.328
# 3                                       Frank Parker         0.275
# 4                                         Phil Regan         0.418
#
#    duration_ms  energy  explicit  instrumentalness  key  liveness  loudness  \
# 0       831667   0.211         0          0.878000   10     0.665   -20.096
# 1       180533   0.341         0          0.000000    7     0.160   -12.441
# 2       500062   0.166         0          0.913000    3     0.101   -14.850
# 3       210000   0.309         0          0.000028    5     0.381    -9.316
# 4       166693   0.193         0          0.000002    3     0.229   -10.096
#
#    mode                                               name  popularity  \
# 0     1  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1     1                            Clancy Lowered the Boom           5
# 2     1                                          Gati Bali           5
# 3     1                                          Danny Boy           3
# 4     1                        When Irish Eyes Are Smiling           2
#
#    speechiness    tempo  duration_min Song Decade
# 0       0.0366   80.954         13.86       1920s
# 1       0.4150   60.936          3.01       1920s
# 2       0.0339  110.339          8.33       1920s
# 3       0.0354  100.109          3.50       1920s
# 4       0.0380  101.665          2.78       1920s

# %%
df.duration_min.sum()/(24*365*60)
# Out:
# np.float64(1.245739897260274)

# %% [markdown]
# **Observation** - Spotify has 454.06 days of music or 1.24 year of continous listening. In other words it will take 1.24 years for you to listen to all the songs

# %%
#Drop the columns
df.drop(['duration_ms'],inplace=True,axis=1)

# %%
plt.rcParams.update({'font.size': 22})

# %%
#Visualisation of Variability for each column in the dataframe
fig,ax = plt.subplots(3,4,figsize=(20,20))

sns.distplot(df['valence'],ax=ax[0,0])
sns.distplot(df['year'],ax=ax[0,1])
sns.distplot(df['acousticness'],ax=ax[0,2])
sns.distplot(df['danceability'],ax=ax[0,3])
#sns.distplot(df['duration_min'],ax=ax[1,1])
sns.distplot(df['energy'],ax=ax[1,0])
sns.distplot(df['key'],ax=ax[1,1])
sns.distplot(df['liveness'],ax=ax[1,2])
sns.distplot(df['loudness'],ax=ax[1,3])
sns.distplot(df['popularity'],ax=ax[2,0])
sns.distplot(df['speechiness'],ax=ax[2,1])
sns.distplot(df['tempo'],ax=ax[2,2])
sns.distplot(df['mode'],ax=ax[2,3])
# Out:
# <Axes: xlabel='mode', ylabel='Density'>

# %%
pip install Jinja2
# Out:
# Requirement already satisfied: Jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from Jinja2) (3.0.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# conver df to numerical
numeric_df = df.select_dtypes(include=['number']) 
# Compute correlation
corr = numeric_df.corr()

# Display heatmap using Pandas styling
corr.style.background_gradient(cmap='BrBG_r').format(precision=2)
# Out:
# <style type="text/css">
# #T_1a7f0_row0_col0, #T_1a7f0_row1_col1, #T_1a7f0_row2_col2, #T_1a7f0_row3_col3, #T_1a7f0_row4_col4, #T_1a7f0_row5_col5, #T_1a7f0_row6_col6, #T_1a7f0_row7_col7, #T_1a7f0_row8_col8, #T_1a7f0_row9_col9, #T_1a7f0_row10_col10, #T_1a7f0_row11_col11, #T_1a7f0_row12_col12, #T_1a7f0_row13_col13, #T_1a7f0_row14_col14 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col1, #T_1a7f0_row1_col3, #T_1a7f0_row10_col1 {
#   background-color: #abdfd7;
#   color: #000000;
# }
# #T_1a7f0_row0_col2 {
#   background-color: #8fd3c9;
#   color: #000000;
# }
# #T_1a7f0_row0_col3, #T_1a7f0_row9_col11 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_1a7f0_row0_col4, #T_1a7f0_row3_col0 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_1a7f0_row0_col5, #T_1a7f0_row5_col13, #T_1a7f0_row10_col3, #T_1a7f0_row10_col13 {
#   background-color: #2b8d85;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col6, #T_1a7f0_row14_col13 {
#   background-color: #1a7e76;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col7, #T_1a7f0_row4_col7 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col8, #T_1a7f0_row1_col6, #T_1a7f0_row2_col14, #T_1a7f0_row9_col10, #T_1a7f0_row10_col8 {
#   background-color: #01645b;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col9 {
#   background-color: #f6eed9;
#   color: #000000;
# }
# #T_1a7f0_row0_col10, #T_1a7f0_row5_col14, #T_1a7f0_row9_col7 {
#   background-color: #0a6f67;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col11, #T_1a7f0_row7_col9, #T_1a7f0_row7_col11, #T_1a7f0_row11_col3 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_1a7f0_row0_col12 {
#   background-color: #2d8f87;
#   color: #f1f1f1;
# }
# #T_1a7f0_row0_col13, #T_1a7f0_row9_col5, #T_1a7f0_row13_col2 {
#   background-color: #87d0c5;
#   color: #000000;
# }
# #T_1a7f0_row0_col14, #T_1a7f0_row1_col12, #T_1a7f0_row2_col1, #T_1a7f0_row2_col4, #T_1a7f0_row2_col5, #T_1a7f0_row2_col9, #T_1a7f0_row2_col11, #T_1a7f0_row2_col13, #T_1a7f0_row3_col8, #T_1a7f0_row4_col2, #T_1a7f0_row6_col0, #T_1a7f0_row6_col3, #T_1a7f0_row7_col10, #T_1a7f0_row9_col6, #T_1a7f0_row10_col7, #T_1a7f0_row11_col12, #T_1a7f0_row14_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col0, #T_1a7f0_row8_col3, #T_1a7f0_row13_col12, #T_1a7f0_row13_col14 {
#   background-color: #147870;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col2, #T_1a7f0_row1_col10, #T_1a7f0_row11_col10, #T_1a7f0_row14_col12 {
#   background-color: #015b52;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col4 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_1a7f0_row1_col5 {
#   background-color: #b4e2db;
#   color: #000000;
# }
# #T_1a7f0_row1_col7, #T_1a7f0_row2_col12, #T_1a7f0_row11_col7 {
#   background-color: #066b63;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col8 {
#   background-color: #004b40;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col9, #T_1a7f0_row4_col11 {
#   background-color: #e6cd92;
#   color: #000000;
# }
# #T_1a7f0_row1_col11 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_1a7f0_row1_col13, #T_1a7f0_row5_col2 {
#   background-color: #76c6ba;
#   color: #000000;
# }
# #T_1a7f0_row1_col14, #T_1a7f0_row8_col5 {
#   background-color: #4aa69d;
#   color: #f1f1f1;
# }
# #T_1a7f0_row2_col0 {
#   background-color: #004135;
#   color: #f1f1f1;
# }
# #T_1a7f0_row2_col3 {
#   background-color: #003f34;
#   color: #f1f1f1;
# }
# #T_1a7f0_row2_col6 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_1a7f0_row2_col7, #T_1a7f0_row6_col5, #T_1a7f0_row6_col13 {
#   background-color: #015f56;
#   color: #f1f1f1;
# }
# #T_1a7f0_row2_col8, #T_1a7f0_row4_col10 {
#   background-color: #01584f;
#   color: #f1f1f1;
# }
# #T_1a7f0_row2_col10, #T_1a7f0_row5_col0 {
#   background-color: #187c74;
#   color: #f1f1f1;
# }
# #T_1a7f0_row3_col1, #T_1a7f0_row13_col9 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_1a7f0_row3_col2, #T_1a7f0_row12_col1 {
#   background-color: #6dbfb4;
#   color: #000000;
# }
# #T_1a7f0_row3_col4 {
#   background-color: #f6eedb;
#   color: #000000;
# }
# #T_1a7f0_row3_col5 {
#   background-color: #c1e8e2;
#   color: #000000;
# }
# #T_1a7f0_row3_col6, #T_1a7f0_row4_col6, #T_1a7f0_row6_col7, #T_1a7f0_row7_col8 {
#   background-color: #016259;
#   color: #f1f1f1;
# }
# #T_1a7f0_row3_col7, #T_1a7f0_row5_col8, #T_1a7f0_row12_col7 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_1a7f0_row3_col9 {
#   background-color: #f5f0e0;
#   color: #000000;
# }
# #T_1a7f0_row3_col10, #T_1a7f0_row14_col10 {
#   background-color: #01564d;
#   color: #f1f1f1;
# }
# #T_1a7f0_row3_col11 {
#   background-color: #f0f4f3;
#   color: #000000;
# }
# #T_1a7f0_row3_col12, #T_1a7f0_row11_col5, #T_1a7f0_row14_col6 {
#   background-color: #a3dbd3;
#   color: #000000;
# }
# #T_1a7f0_row3_col13, #T_1a7f0_row7_col12 {
#   background-color: #258880;
#   color: #f1f1f1;
# }
# #T_1a7f0_row3_col14, #T_1a7f0_row6_col12 {
#   background-color: #004e44;
#   color: #f1f1f1;
# }
# #T_1a7f0_row4_col0 {
#   background-color: #e2f0ee;
#   color: #000000;
# }
# #T_1a7f0_row4_col1 {
#   background-color: #dcbc75;
#   color: #000000;
# }
# #T_1a7f0_row4_col3, #T_1a7f0_row12_col4 {
#   background-color: #bfe7e1;
#   color: #000000;
# }
# #T_1a7f0_row4_col5 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_1a7f0_row4_col8, #T_1a7f0_row13_col5 {
#   background-color: #389991;
#   color: #f1f1f1;
# }
# #T_1a7f0_row4_col9 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_1a7f0_row4_col12, #T_1a7f0_row12_col14 {
#   background-color: #016058;
#   color: #f1f1f1;
# }
# #T_1a7f0_row4_col13 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_1a7f0_row4_col14 {
#   background-color: #33958d;
#   color: #f1f1f1;
# }
# #T_1a7f0_row5_col1 {
#   background-color: #f5f3ec;
#   color: #000000;
# }
# #T_1a7f0_row5_col3, #T_1a7f0_row10_col4, #T_1a7f0_row12_col2 {
#   background-color: #c9eae6;
#   color: #000000;
# }
# #T_1a7f0_row5_col4, #T_1a7f0_row5_col12, #T_1a7f0_row8_col4 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_1a7f0_row5_col6, #T_1a7f0_row7_col0 {
#   background-color: #2f9189;
#   color: #f1f1f1;
# }
# #T_1a7f0_row5_col7, #T_1a7f0_row8_col10, #T_1a7f0_row9_col2, #T_1a7f0_row13_col7, #T_1a7f0_row14_col3 {
#   background-color: #046961;
#   color: #f1f1f1;
# }
# #T_1a7f0_row5_col9, #T_1a7f0_row13_col11 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_1a7f0_row5_col10 {
#   background-color: #00493e;
#   color: #f1f1f1;
# }
# #T_1a7f0_row5_col11 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_1a7f0_row6_col1, #T_1a7f0_row11_col14, #T_1a7f0_row12_col8, #T_1a7f0_row13_col6 {
#   background-color: #3e9d95;
#   color: #f1f1f1;
# }
# #T_1a7f0_row6_col2 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_1a7f0_row6_col4, #T_1a7f0_row12_col9 {
#   background-color: #67bbb0;
#   color: #000000;
# }
# #T_1a7f0_row6_col8 {
#   background-color: #005046;
#   color: #f1f1f1;
# }
# #T_1a7f0_row6_col9, #T_1a7f0_row10_col12, #T_1a7f0_row11_col2, #T_1a7f0_row13_col8, #T_1a7f0_row14_col7 {
#   background-color: #01655d;
#   color: #f1f1f1;
# }
# #T_1a7f0_row6_col10 {
#   background-color: #015a50;
#   color: #f1f1f1;
# }
# #T_1a7f0_row6_col11, #T_1a7f0_row8_col13, #T_1a7f0_row10_col0 {
#   background-color: #298b83;
#   color: #f1f1f1;
# }
# #T_1a7f0_row6_col14 {
#   background-color: #4da89f;
#   color: #f1f1f1;
# }
# #T_1a7f0_row7_col1, #T_1a7f0_row14_col2 {
#   background-color: #bce5df;
#   color: #000000;
# }
# #T_1a7f0_row7_col2, #T_1a7f0_row8_col2 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_1a7f0_row7_col3 {
#   background-color: #4faaa1;
#   color: #f1f1f1;
# }
# #T_1a7f0_row7_col4 {
#   background-color: #dbefec;
#   color: #000000;
# }
# #T_1a7f0_row7_col5, #T_1a7f0_row8_col14, #T_1a7f0_row12_col0, #T_1a7f0_row12_col6 {
#   background-color: #35978f;
#   color: #f1f1f1;
# }
# #T_1a7f0_row7_col6, #T_1a7f0_row11_col13 {
#   background-color: #70c1b6;
#   color: #000000;
# }
# #T_1a7f0_row7_col13, #T_1a7f0_row11_col0 {
#   background-color: #278a82;
#   color: #f1f1f1;
# }
# #T_1a7f0_row7_col14, #T_1a7f0_row9_col14, #T_1a7f0_row14_col5 {
#   background-color: #1f827a;
#   color: #f1f1f1;
# }
# #T_1a7f0_row8_col0 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_1a7f0_row8_col1, #T_1a7f0_row9_col13, #T_1a7f0_row10_col11 {
#   background-color: #a0dad1;
#   color: #000000;
# }
# #T_1a7f0_row8_col6 {
#   background-color: #5eb5aa;
#   color: #f1f1f1;
# }
# #T_1a7f0_row8_col7 {
#   background-color: #02675f;
#   color: #f1f1f1;
# }
# #T_1a7f0_row8_col9 {
#   background-color:

# %% [markdown]
# **Observation** As you can see above, year, danceability, energy, loudness and tempo are important features for predicting popularity.
#
# Valence and Danceability are highly related and so is speechiness and Danceability

# %% [markdown]
# From the above correlation table we can derive some basic insights as to what attributes make a song more popular.
#
# 1) As expected popularity is highly correlated with the year released. This makes sense as the Spotify algorithm which makes this decision generates it's "popularity" metric by not just how many streams a song receives, but also how recent those streams are.
#
# 2) Energy also seems to influence a song's popularity. Many popular songs are energetic, though not necessarily dance songs. Because the correlation here is not too high, low energy songs do have some potential to be more popular.
#
# 3) Acousticness seems to be uncorrelated with popularity. Most popular songs today have either electronic or electric instruments in them. It is very rare that a piece of music played by a chamber orchestra or purely acoustic band becomes immesely popular (though, again, not impossible).
#
# Other things worth noting:
#
# 1) Loudness and energy are highly correlated. This makes some sense as energy is definately influence by the volume the music is being played at.
#
# 2) Acousticness is highly negatively correlated with energy, loudness, and year.
#
# 3) Valence and dancability are highly coorelated. Dance songs are usually happier and in a major key
#
# Thus, from this data, it would be better for an artist to create a high energy song with either electric instruments or electronic songs to have the best chance at generating the most popularity.

# %% [markdown]
# ## Most Popular Tracks

# %%
import plotly.express as px

# Get the top 15 popular tracks
popular_tracks = df.groupby("name")['popularity'].mean().sort_values(ascending=False).head(15).reset_index()

# Create a bar chart
fig = px.bar(popular_tracks, x='popularity', y='name', orientation='h', color='popularity', 
             title='Top 15 Popular Tracks', color_continuous_scale='viridis')

fig.update_layout(xaxis_title='Popularity', yaxis_title='Tracks', yaxis=dict(autorange="reversed"))
fig.show()

# %%
df.groupby("name")['popularity'].mean().sort_values(ascending=False).head(15)
# Out:
# name
# Dakiti                                  100.0
# Mood (feat. iann dior)                   99.0
# Blinding Lights                          96.0
# What You Know Bout Love                  96.0
# WAP (feat. Megan Thee Stallion)          96.0
# you broke me first                       95.0
# Holy (feat. Chance The Rapper)           95.0
# Lonely (with benny blanco)               95.0
# Head & Heart (feat. MNEK)                94.0
# Relación - Remix                         94.0
# Laugh Now Cry Later (feat. Lil Durk)     93.0
# Therefore I Am                           93.0
# La Tóxica                                92.0
# La Nota                                  92.0
# Se Te Nota (with Guaynaa)                92.0
# Name: popularity, dtype: float64

# %% [markdown]
# As we have noted throughout this project is that popularity is heavily dependent on the timeframe. As we see, Dakiti has the highest popularity rating by this graph, but was released on October 30th, 2020. Using this data in our regression will give us a snapshot as to the attributes popular songs have for mid-2020, but may not work or become less relevant once we get further from this date.

# %%
# Top 20 Artists with Popularity
top_20_artists = df.groupby("artists")['popularity'].sum().sort_values(ascending=False).head(20).reset_index()
# Create a bar chart
fig = px.bar(top_20_artists, x='popularity', y='artists', orientation='h', color='popularity', 
             title='Top 20 Artists with Popularity', color_continuous_scale='viridis')
fig.update_layout(xaxis_title='Popularity', yaxis_title='Artists', yaxis=dict(autorange="reversed"))
fig.show()

# %% [markdown]
# **Observation** - Most Popular artist from 1921-2020 - Beatles

# %%
# visualize the popularity of The Beatles songs over the year
Beatles = df[df['artists'] == 'The Beatles']
plt.rcParams['figure.figsize'] = (11,7)
# line plot passing x,y
sns.lineplot(x='year', y='popularity', data=Beatles, color='green')
# Labels
plt.title("The Beatles Popularity")
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.show()

# %%
columns = ["acousticness", "danceability", "energy", "speechiness", "liveness", "valence"]
df_year[columns].plot(figsize=(15, 8), linewidth=2)
plt.title('Audio Characteristics Over the Years', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Characteristics', fontsize=15)
plt.legend(columns, title="Features", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# **Observation** - Over the Years we can see gradual increase for Danceability, Energy and gradual decrease for Acousticness

# %% [markdown]
# 1) Acousticness has decreased significantly. Most tracks past 1960 used electric instruments and, especially past the 1980s, electronic sounds. Most recorded music today includes both electric and electronic elements.
#
# 2) Danceability has varied significantly, but has stayed mostly at the same level since 1980.
#
# 3) Energy seems to be inversely related to acousticness: Was very low in the first part of the century, but then rose signficantly after 1960. It looks like it increased even more after 2000 as well.
#
# 4) Speechiness looks like it varied a lot in the first part of the 20th century, but then settled low around 1960. Note we do see a slight increase after 1980. This is likely due to the growth of rap music. Mostly music, however, is still mostly sung.
#
# 5) Liveness looks like it has always stayed relatively low. Most recorded music on Spotify was made with not audience present.
#
# 6) Valence seems to have risen until 2000 with energy and danceability, but has fallen since.

# %%
columns = ['acousticness','danceability', 'duration_min', 'energy', 'explicit',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'popularity', 'speechiness', 'tempo', 'valence']
for col in columns:
       plt.figure(figsize=(15, 5))
       sns.set_style("darkgrid")
       sns.lineplot(data=df, x='year', y=col, ci=None)
       plt.title(f'Trend of {col} over the years')
       plt.xlabel('Year')
       plt.ylabel(col.capitalize())
       plt.show()

# %% [markdown]
# **Observation**
# - Acousticness and instrumentaliness decreases from time to time (lowest in 2020)
# - Danceability, Energy, Explicit, Loudness, and Tempo increases through time
# - Speechiness stays within 0.1 to 0.2 after 1960

# %% [markdown]
# ## Artist with Maximum number of songs

# %%
y=pd.DataFrame(df['artists'].value_counts().head()).reset_index()
y.columns=['Artists','Songs_Count']
y
# Out:
#              Artists  Songs_Count
# 0   Эрнест Хемингуэй         1211
# 1  Эрих Мария Ремарк         1068
# 2   Francisco Canaro          942
# 3      Frank Sinatra          630
# 4    Ignacio Corsini          628

# %% [markdown]
# **Observation** - 'Эрнест Хемингуэй' is the artist with 1211 songs

# %% [markdown]
# ## Number of songs released Year Wise

# %%
year = pd.DataFrame(df['year'].value_counts())
year = year.sort_index()
ax=year.plot(kind='line',figsize=(15,8) ,color='#6f4a8e', linewidth=2)
plt.title("Number of songs released Yearwise",y=1.05,fontsize=20)
plt.xlabel('Years')
plt.ylabel('Count')
ax.axes.get_xaxis().set_visible(True)

# %% [markdown]
# **Observation** -
# - 2103 songs are released in year 2018
#
# - From the dataset creator's own comments, it's likely these are the 2000 most popular songs from each selected year.

# %%
keypop = pd.DataFrame(df.groupby('key')['popularity'].mean()).reset_index()
keypop.replace({'key' : { 0 : 'C', 1 : 'C#', 2 : 'D', 3 : 'D#', 4 : 'E', 5 : 'F', 6 : 'F#', 
                        7 : 'G', 8 : 'G#', 9 : 'A', 10 : 'A#', 11 : 'B'}} , inplace=True)

fig = plt.figure(figsize=(15,6))
plt.bar( keypop['key'],
         keypop['popularity'],
         width=0.45,
         color = ['#844685','#f3c623'])
plt.title('Key VS Popularity',y=1.1,fontsize=20)
plt.xlabel('Key')
plt.ylabel('Popularity')
ax.axes.get_xaxis().set_visible(True)

# %%
# Count occurrences of each key
key = df['key'].value_counts().reset_index()

# Rename columns correctly
key.columns = ['key', 'count']

# Sort by 'key' (which was previously 'index')
key.sort_values('key', inplace=True)

# Replace numeric keys with musical note names
key.replace({'key': { 0: 'C', 1: 'C#', 2: 'D', 3: 'D#', 4: 'E', 5: 'F', 
                      6: 'F#', 7: 'G', 8: 'G#', 9: 'A', 10: 'A#', 11: 'B'}}, inplace=True)

# Plot
fig = plt.figure(figsize=(15,6))
plt.bar(key['key'], key['count'], width=0.45, color=['#ffa931','#00a8cc'])
plt.title('Frequency Count For Key', y=1.1, fontsize=20)
plt.xlabel('Key')
plt.ylabel('Frequency')

plt.show()  # Ensure the plot is displayed

# %%
top10_genres = df_by_genres.nlargest(10, 'popularity')

fig = px.bar(top10_genres, x='genres', y=['valence', 'energy', 'danceability', 'acousticness'], barmode='group')
fig.show()

# %%
df_by_genres['genres'].nunique()
# Out:
# 2973

# %%
df_artist.artists
# Out:
# 0                         "Cats" 1981 Original London Cast
# 1                                "Cats" 1983 Broadway Cast
# 2              "Fiddler On The Roof” Motion Picture Chorus
# 3           "Fiddler On The Roof” Motion Picture Orchestra
# 4        "Joseph And The Amazing Technicolor Dreamcoat"...
#                                ...
# 28675                                                  麥志誠
# 28676                                                  黃品源
# 28677                                                  黃國隆
# 28678                                                   黑豹
# 28679                                                  조정현
# Name: artists, Length: 28680, dtype: object

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# We need to design a ML Model that can predicts the Popularity based on the features available. In order to select the features for the model I am using [YellowbrickFeature Correlation Visualizer](https://www.scikit-yb.org/en/latest/api/target/feature_correlation.html).
#
# This visualizer calculates Pearson correlation coefficients and mutual information between features and the dependent variable. This visualization can be used in feature selection to identify features with high correlation or large mutual information with the dependent variable.

# %%
# Calculate the correlation matrix
feature_names = ['acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence','duration_min','explicit','key','mode','year']

X, y = df[feature_names], df['popularity']

correlation_matrix = X.corrwith(y)

# Convert to a DataFrame for better visualization
correlation_df = correlation_matrix.to_frame(name='Correlation').reset_index()
correlation_df.rename(columns={'index': 'Feature'}, inplace=True)

# Sort by correlation values (descending order)
correlation_df = correlation_df.sort_values(by='Correlation', ascending=False)

# Plot the correlation using seaborn
plt.figure(figsize=(10, 8))
sns.barplot(data=correlation_df, x='Correlation', y='Feature', palette='viridis')
plt.title('Feature Correlation with Popularity')
plt.xlabel('Correlation')
plt.ylabel('Feature', fontsize=12)
plt.show()

# %% [markdown]
# **Observation** From the above graph it is clear that *5* features with negative correlation and *9* features with positive correlation
#
# **Feature Selection** - Choosing which Features can be used in model
#
# 1) id: id is unique for each track, therfore cannot assist a model and will be dropped.
#
# 2) name: There are 132,940 unique values. This is bit problematic categorical feature to insert in a model, and will be dropped.
#
# 3) release_date/year: Release date contains full date along with year. So instead of keeping both the columns Release_date can be dropped and year can be inserted into model

# %% [markdown]
# ## Pre Processing

# %%
cols = list(pd.read_csv('data/data.csv', nrows =1))
df1 = pd.read_csv('data/data.csv', usecols=[i for i in cols if i not in ['id','name','release_date']])

# Remove duplicated
df1 = df1[~df1.duplicated()==1]

#Split the data to train and test
X_train, X_test, y_train, y_test = train_test_split(df1.drop('popularity', axis=1), df1['popularity'], test_size = 0.2, random_state = 42)

# %%
X_train.head()
# Out:
#         valence  year  acousticness                       artists  \
# 74462     0.484  2017        0.2060          ['Christian French']
# 146712    0.763  1975        0.5110  ['The Marshall Tucker Band']
# 158411    0.931  1959        0.8230               ["Anita O'Day"]
# 109710    0.329  1942        0.0117        ['Orchestra Studio 7']
# 128817    0.585  1960        0.7820              ['Quincy Jones']
#
#         danceability  duration_ms  energy  explicit  instrumentalness  key  \
# 74462          0.550       234192   0.580         0          0.000001    4
# 146712         0.528       150933   0.812         0          0.000284    2
# 158411         0.460       125707   0.303         0          0.000000    0
# 109710         0.582       224967   0.443         0          0.868000    7
# 128817         0.681       138467   0.312         0          0.072800    8
#
#         liveness  loudness  mode  speechiness    tempo
# 74462     0.1190    -7.687     0       0.0784   82.270
# 146712    0.1570    -4.983     1       0.0517  110.442
# 158411    0.0676   -12.567     0       0.1070  170.608
# 109710    0.0895   -12.506     1       0.0307   94.825
# 128817    0.1690   -11.488     1       0.0723  121.058

# %% [markdown]
# Here we need to replace/modify few data
#
# - object data of the artists with some numerical indicator that identify the artist.
# - Eliminates Zero values from tempo columns and replace it
# - standardizing Instrumental Criteria with numeric values
# - We use OneHotEncoder from SKlearn to create dummies
# - MinMaxScaling for relevant features
# - Target Scaling

# %% [markdown]
# ### Features Transformations

# %%
class Artists:
    """
     This transformer recives a DF with a feature 'artists' of dtype object
      and convert the feature to a float value as follows:
      1. Replace the data with the artists mean popularity
      2. Replace values where artists appear less than MinCnt with y.mean()
      3. Replace values where artists appear more than MaxCnt with 0
      
      PARAMETERS:
      ----------
      MinCnt (int): Minimal treshold of artisits apear in dataset, default = 3
      MaxCnt (int): Maximal treshold of artisits apear in dataset, default = 600

      RERTURN:
      ----------
      A DataFrame with converted artists str feature to ordinal floats
    
    """
    def __init__(self, MinCnt = 3.0, MaxCnt = 600.0):
        self.MinCnt = MinCnt
        self.MaxCnt = MaxCnt
        self.artists_df = None

    def fit (self, X, y):
        self.artists_df =  y.groupby(X.artists).agg(['mean', 'count'])
        self.artists_df.loc['unknown'] = [y.mean(), 1]
        self.artists_df.loc[self.artists_df['count'] <= self.MinCnt, 'mean'] = y.mean()
        self.artists_df.loc[self.artists_df['count'] >= self.MaxCnt, 'mean'] = 0
        return self

    def transform(self, X, y=None):
        X['artists'] = np.where(X['artists'].isin(self.artists_df.index), X['artists'], 'unknown')
        X['artists'] = X['artists'].map(self.artists_df['mean'])
        return X
  
    
#Instrumental Transformer Criteria

def instrumental(X):
    X['instrumentalness'] = list(map((lambda x: 1 if x < 0.1 else (3 if x > 0.95 else 2)), X.instrumentalness))
    
    
class Tempo():
    """Eliminates Zero values from tempo columns and replace it 
       with the median or mean of non-zero values as specified.
       defaut is set to 'median'.
    """

    def __init__(self, method='median'):
        self.method = method

    def transform(self, X):
        if self.method == 'median':
            X.loc[X['tempo']==0, 'tempo'] = X.loc[X['tempo']>0, 'tempo'].median()
        elif self.method == 'mean':
            X.loc[X['tempo']==0, 'tempo'] = X.loc[X['tempo']>0, 'tempo'].mean()
        else:
            raise Exception("Method can be 'median' or 'mean' only!")
        return X

# %%
# Apply Aritists class on train and test seperatly
artists_transformer = Artists(MinCnt=2)
X_train = artists_transformer.fit(X_train, y_train).transform(X_train, y_train)
X_test = artists_transformer.transform(X_test, y_test)

#Apply Instrumental Criteria on train & test seperately
instrumentalness_tranformer = FunctionTransformer(instrumental)
instrumentalness_tranformer.transform(X_train)
instrumentalness_tranformer.transform(X_test)

#Apply Tempo Transformer class on Train & Test seperately
tempo_transformer = Tempo()
X_train = tempo_transformer.transform(X_train)
X_test = tempo_transformer.transform(X_test)

# %% [markdown]
# ### One Hot Encoder
#
# More Info on how to create dummies can be found here [One Hot Encoder Sklearn Library](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)

# %%
ohe = OneHotEncoder(categories='auto', drop='first')

# Train
feature_arr = ohe.fit_transform(X_train[['instrumentalness','key']]).toarray()
columns_key = ['key_'+str(i) for i in list(set(X_train['key'].values))[1:]]
instrumentalness_key = ['ins_'+str(i) for i in list(set(X_train['instrumentalness'].values))[1:]]
feature_labels = columns_key + instrumentalness_key
feature_labels = np.concatenate((feature_labels), axis=None)
features = pd.DataFrame(feature_arr, columns = feature_labels, index = X_train.index)
X_train = pd.concat([X_train, features], axis=1).drop(['key','instrumentalness'], axis=1)

# Test
feature_arr = ohe.fit_transform(X_test[['instrumentalness','key']]).toarray()
columns_key = ['key_'+str(i) for i in list(set(X_test['key'].values))[1:]]
instrumentalness_key = ['ins_'+str(i) for i in list(set(X_test['instrumentalness'].values))[1:]]
feature_labels = columns_key + instrumentalness_key
feature_labels = np.concatenate((feature_labels), axis=None)
features = pd.DataFrame(feature_arr, columns = feature_labels, index = X_test.index)
X_test = pd.concat([X_test, features], axis=1).drop(['key','instrumentalness'], axis=1)

# %% [markdown]
# ### MinMaxScaler

# %%
scaler = MinMaxScaler()
cols = ['artists','duration_ms','loudness','tempo']
X_train[cols] = scaler.fit_transform(X_train[cols])
X_test[cols] = scaler.fit_transform(X_test[cols])

# %% [markdown]
# ## Target Scaling

# %%
# Divide the popularity by 100
y_train = y_train / 100
y_test = y_test / 100

# %% [markdown]
# ## Decision Tree Regressor Model

# %%
def Decision_tree(X_train,y_train,X_test,y_test,min_samples_split,max_leaf_nodes):
    """
    Design ML model and returns r2-score and Mean squared Error for Train and Test Datasets
    
    INPUT:
    :param X_train: 
    :param y_train: 
    :param X_test: 
    :param y_test: 
    :param min_samples_split: 
    :param max_leaf_nodes: 
    OUTPUT:
    train_rmse - Root Mean Squared Error for Train dataset
    test_rmse - Root Mean Squared Error for Train dataset
    r2_train - r2-score for Train Dataset
    r2_test - r2-score for Test Dataset
    y_train_pred and y_test_pred - For Visualizing purpose
    mae - Mean Absolute Error
    """
    
    
    tree = DecisionTreeRegressor(max_leaf_nodes =max_leaf_nodes , min_samples_split =min_samples_split )
    tree.fit(X_train, y_train)
    y_train_pred = tree.predict(X_train)
    train_rmse = np.sqrt(mse(y_train, y_train_pred))
    
    y_test_pred = tree.predict(X_test)
    test_rmse = np.sqrt(mse(y_test, y_test_pred))
    
    r2_train = r2_score(y_train, y_train_pred)
    
    r2_test= r2_score(y_test, y_test_pred)
    
    mae = (abs(y_test - y_test_pred)).mean() 
    
    return train_rmse,test_rmse,r2_train,r2_test,y_train_pred,y_test_pred,mae

train_rmse, test_rmse, r2_train, r2_test,y_train_pred,y_test_pred,mae= Decision_tree(X_train,y_train,X_test,y_test,min_samples_split = 200,max_leaf_nodes=167)

print("Root Mean Squared Error for Train dataset is {}".format(train_rmse))
print("Root Mean Squared Error for Test  dataset is {}".format(test_rmse))
print("r2-score for Train Dataset is {}".format(r2_train))
print("r2-score for Test Dataset is {}".format(r2_test))
print("Mean Absolute Error for Test dataset is {}".format(mae))
# Out:
# Root Mean Squared Error for Train dataset is 0.08769988801533653
# Root Mean Squared Error for Test  dataset is 0.10884646442377646
# r2-score for Train Dataset is 0.8381548180085765
# r2-score for Test Dataset is 0.748962091683729
# Mean Absolute Error for Test dataset is 0.07926579723971673

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((136020, 26), (136020,), (34005, 26), (34005,))

# %%
y_train_pred.shape, y_test_pred.shape
# Out:
# ((136020,), (34005,))

# %%
#Plot the results for Train Datasets
plt.rcParams['figure.figsize'] = (10,7)
ax = sns.scatterplot(x=y_train, y=y_train_pred)
ax.plot(y_train, y_train, 'r')
ax.set_ylabel('popularity prediction')
ax.set_title('Train Dataset')
plt.show()

# %%
#plot the results for Test dataset
plt.rcParams['figure.figsize'] = (10,7)
ax = sns.scatterplot(x=y_test, y=y_test_pred)
ax.plot(y_test, y_test, 'r')
ax.set_ylabel('popularity prediction')
ax.set_title('Test Dataset')
plt.show()

# %% [markdown]
# ## Decision Tree with GridSearch CV
# Using GridSearchCV to find the optimal hyperparameters for the decision tree to predict song popularity.

# %%
n_features = df.shape[1]
n_samples = df.shape[0]
 
grid = GridSearchCV(DecisionTreeRegressor(random_state=0), cv=3, n_jobs=-1, verbose=5,
                    param_grid ={
                    'max_depth': [None,5,6,7,8,9,10,11],
                    'max_features': [None, 'sqrt', 'auto', 'log2', 0.3,0.5,0.7, n_features//2, n_features//3, ],
                    'min_samples_split': [2,0.3,0.5, n_samples//2, n_samples//3, n_samples//5],
                    'min_samples_leaf':[1, 0.3,0.5, n_samples//2, n_samples//3, n_samples//5]},
                    )
 
grid.fit(X_train, y_train)
print('Train R^2 Score : %.3f'%grid.best_estimator_.score(X_train, y_train))
print('Test R^2 Score : %.3f'%grid.best_estimator_.score(X_test,y_test))
print('Best R^2 Score Through Grid Search : %.3f'%grid.best_score_)
print('Best Parameters : ',grid.best_params_)
# Out:
# Fitting 3 folds for each of 2592 candidates, totalling 7776 fits
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.5;, score=0.696 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.3;, score=0.777 total time=   0.3s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.5;, score=0.700 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.3;, score=0.775 total time=   0.4s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.3;, score=0.770 total time=   0.3s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=85044;, score=0.603 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=85044;, score=0.604 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=85044;, score=0.597 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=0.5;, score=0.698 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=56696;, score=0.700 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=34017;, score=0.696 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=56696;, score=0.696 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=34017;, score=0.700 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=56696;, score=0.698 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=34017;, score=0.698 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.700 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=2;, score=0.696 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=2;, score=0.700 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=2;, score=0.698 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.696 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.700 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.698 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.698 total time=   0.3s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=85044;, score=0.603 total time=   0.3s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.696 total time=   0.3s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=85044;, score=0.597 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=85044;, score=0.604 total time=   0.3s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=56696;, score=0.696 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=56696;, score=0.698 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=56696;, score=0.700 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=34017;, score=0.696 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=34017;, score=0.700 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=2;, score=0.011 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.3, min_samples_split=34017;, score=0.698 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=2;, score=0.066 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.3;, score=0.066 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.3;, score=0.011 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.5;, score=0.066 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=0.5;, score=0.011 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=85044;, score=0.066 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=85044;, score=0.011 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=56696;, score=0.011 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=56696;, score=0.066 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=34017;, score=0.011 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=0.5, min_samples_split=34017;, score=0.066 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=0.686 total time=   2.4s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=0.677 total time=   2.5s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2;, score=0.675 total time=   2.5s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=2;, score=0.591 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.3;, score=0.591 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.3;, score=0.590 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.3;, score=0.588 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=2;, score=0.590 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=2;, score=0.588 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.5;, score=0.590 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.5;, score=0.591 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=85044;, score=0.590 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=85044;, score=0.591 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=85044;, score=0.588 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=56696;, score=0.591 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=0.5;, score=0.588 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=56696;, score=0.590 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=56696;, score=0.588 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.3;, score=0.322 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=34017;, score=0.591 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=34017;, score=0.588 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=None, min_samples_leaf=34017, min_samples_split=34017;, score=0.590 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.3;, score=0.320 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.5;, score=0.270 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.3;, score=0.311 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.5;, score=0.277 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=85044;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=0.5;, score=0.266 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=85044;, score=0.224 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=85044;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=56696;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=56696;, score=0.214 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=56696;, score=0.224 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.621 total time=   0.5s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=34017;, score=0.287 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.634 total time=   0.5s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=2;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=2;, score=0.224 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=34017;, score=0.294 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=34017;, score=0.282 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2;, score=0.622 total time=   0.6s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=2;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.224 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=85044;, score=0.219 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=56696;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=56696;, score=0.224 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.214 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=85044;, score=0.214 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=85044;, score=0.224 total time=   0.3s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=56696;, score=0.214 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=34017;, score=0.219 total time=   0.2s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=34017;, score=0.224 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.3, min_samples_split=34017;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=2;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.3;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.5;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=2;, score=0.224 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=2;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.5;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.3;, score=0.214 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=85044;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.3;, score=0.219 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=56696;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=56696;, score=0.214 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=0.5;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=85044;, score=0.219 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=34017;, score=0.224 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=85044;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=56696;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=34017;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=sqrt, min_samples_leaf=34017, min_samples_split=34017;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.3, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=0.5, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=85044, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=56696, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.3;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=0.5;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=85044;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=56696;, score=nan total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=34017, min_samples_split=34017;, score=nan total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=0.5;, score=0.346 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=56696;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=2;, score=0.214 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=34017;, score=0.496 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=56696;, score=0.224 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=0.3;, score=0.510 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=85044;, score=0.219 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=85044;, score=0.224 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=56696;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.224 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=85044;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=34017;, score=0.484 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=85044;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=0.3;, score=0.484 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.214 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=85044;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=2;, score=0.219 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=34017;, score=0.490 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=56696;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=85044;, score=0.219 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=0.5;, score=0.348 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=2;, score=0.224 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=56696;, score=0.224 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=0.5;, score=0.351 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=56696;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=34017;, score=0.219 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=34017;, score=0.224 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.3, min_samples_split=34017;, score=0.214 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.1s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.2s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2;, score=0.616 total time=   0.7s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.1s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.1s
# ...
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=0.5;, score=0.289 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=2;, score=0.289 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.3;, score=0.310 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=34017;, score=0.294 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=56696;, score=0.219 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=85044;, score=0.291 total time=   0.1s
# [CV 1/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=0.3;, score=0.291 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=2;, score=0.798 total time=   0.4s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=2;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=56696;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=34017;, score=0.289 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.3;, score=0.303 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=0.3;, score=0.294 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=85044;, score=0.294 total time=   0.1s
# [CV 3/3] END max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2;, score=0.820 total time=   0.8s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.219 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=56696;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.5;, score=0.225 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=0.3;, score=0.289 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=85044;, score=0.289 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.5;, score=0.228 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=34017;, score=0.297 total time=   0.1s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.3;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=0.3;, score=0.471 total time=   0.1s
# [CV 1/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=56696;, score=0.291 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=85044;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.5;, score=0.219 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=34017;, score=0.299 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=34017, min_samples_split=56696;, score=0.294 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=85044;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=85044;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=0.3;, score=0.475 total time=   0.1s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=34017;, score=0.291 total time=   0.1s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=56696;, score=0.219 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=0.5;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=85044;, score=0.224 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=2;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=56696;, score=0.224 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=0.3;, score=0.716 total time=   0.2s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=85044;, score=0.219 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=85044;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=2;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=56696;, score=0.214 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.782 total time=   0.3s
# [CV 3/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=0.3;, score=0.467 total time=   0.1s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=34017;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=34017;, score=0.224 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=0.5;, score=0.346 total time=   0.1s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.3, min_samples_split=34017;, score=0.214 total time=   0.1s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=9, min_samples_leaf=1, min_samples_split=0.5;, score=0.351 total time=   0.1s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=85044, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.771 total time=   0.2s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.3;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=2;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=0.5, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=0.5;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=85044;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=56696;, score=-0.000 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=56696, min_samples_split=34017;, score=-0.000 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=2;, score=0.219 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=2;, score=0.766 total time=   0.2s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=1, min_samples_split=0.3;, score=0.303 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=2;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=2;, score=0.214 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.5;, score=0.224 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.3;, score=0.219 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.5;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.3;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.3;, score=0.214 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=0.5;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=85044;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=85044;, score=0.224 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=56696;, score=0.214 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=34017;, score=0.219 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=56696;, score=0.224 total time=   0.0s
# [CV 2/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=34017;, score=0.224 total time=   0.0s
# [CV 1/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=56696;, score=0.219 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=85044;, score=0.214 total time=   0.0s
# [CV 3/3] END max_depth=11, max_features=6, min_samples_leaf=34017, min_samples_split=34017;, score=0.214 total time=   0.0s
# Train R^2 Score : 0.840
# Test R^2 Score : 0.766
# Best R^2 Score Through Grid Search : 0.829
# Best Parameters :  {'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Decision tree with tuned hyperparameters using GridSearchCV
dec_tree2 = DecisionTreeRegressor(max_depth=9, max_features=None, 
                                  min_samples_leaf=1, min_samples_split=2, random_state=0)
dec_tree2.fit(X_train,y_train)
y_test_pred2 = dec_tree2.predict(X_test)
mae2 = mean_absolute_error(y_test, y_test_pred2)
print(f'Mean absolute error of this model: {mae2:.3f}')
# Out:
# Mean absolute error of this model: 0.073

# %% [markdown]
# ## Tweaking the max_leaf_nodes argument

# %%
RMSE3_train, RMSE3_test = [], []

for i in range(2,200):
    tree = DecisionTreeRegressor(random_state = 15, max_leaf_nodes=i)
    tree.fit(X_train, y_train)
    y_train_pred = tree.predict(X_train).clip(0, 1)
    train_rmse = np.sqrt(mse(y_train, y_train_pred))
    RMSE3_train.append(train_rmse.round(3))
    y_test_pred = tree.predict(X_test).clip(0, 1)
    test_rmse = np.sqrt(mse(y_test, y_test_pred))
    RMSE3_test.append(test_rmse.round(3))

# %%
x = np.arange(2, 200)
ax = sns.lineplot(x=x, y=RMSE3_train)
sns.lineplot(x=x, y=RMSE3_test, ax=ax)
ax.axvline(x=178, ymin=0, ymax=0.3, color='blue')
# ax.axvline(x=139, ymin=0.5, ymax=0.8, color='orange')
ax.legend(labels=['RMSE_train', 'RMSE_test'], bbox_to_anchor=(1, 1))
ax.set_xlabel('Max Leaf Nodes')
ax.set_ylabel('RMSE')
ax.set_title('DT with range(0,200)', c='r', fontdict={'c':'r', 'fontsize':14, 'weight':'bold'})
plt.show()

# %%
gap3 = [(RMSE3_train[i]/RMSE3_test[i]) for i, num in enumerate(RMSE3_train)]

print(f'Minimum validiation is: {min(gap3):.3%} in index number {gap3.index(min(gap3))}')
print(f'Maximum validiation is: {max(gap3):.3%} in index number {gap3.index(max(gap3))}')
# Out:
# Minimum validiation is: 76.786% in index number 140
# Maximum validiation is: 101.695% in index number 1

# %% [markdown]
# We also tested the data with different test size, in order to check the influence on the results.
#
# Eventually, the best model was a Decision Tree run with test size = 0.2, max_leaf_nodes = 167, max_depth = 9, min_samples_leaf = 1, min_samples_split = 2.

# %% [markdown]
# ## RandomForest Regressor

# %%
def Randomforest(X_train,y_train,X_test,y_test):
    """
    Design Random Forest Regressor model and returns r2-score and Mean squared Error for Train and Test Datasets
    INPUT:
    :param X_train: 
    :param y_train: 
    :param X_test: 
    :param y_test: 
    OUTPUT:
    Test Accuracy
    Mean Absolute Error
    r2-score for Train and Test datasets
    """
    clf = RandomForestRegressor()
    clf.fit(X_train, y_train)
    
    preds = clf.predict(X_test)

    accuracy = clf.score(X_test, y_test)

    mae = (abs(y_test - preds)).mean() 
    y_train_pred = clf.predict(X_train)
    
    y_test_pred = tree.predict(X_test)

    
    r2_train = r2_score(y_train, y_train_pred)
    
    r2_test= r2_score(y_test, y_test_pred)
    
    return accuracy,mae,r2_train,r2_test

accuracy,mae,r2_train,r2_test =  Randomforest(X_train,y_train,X_test,y_test)
print("Test Accuracy: {:.4f}".format(accuracy*100))
print("Mean Absolute Error: {:.4f} ".format(mae))
print("r2-score of Train Dataset is {} and Test Dataset is {}".format(r2_train*100, r2_test*100))
# Out:
# Test Accuracy: 77.5674
# Mean Absolute Error: 0.0756
# r2-score of Train Dataset is 97.60230610093001 and Test Dataset is 74.66648478363645

# %% [markdown]
# ## Artist Recommendation System
#
# Build a content-based recommendation engine which suggests artists

# %% [markdown]
# ### Normalize Columns

# %%
def normalize_column(col):
    """
    col - column in the dataframe which needs to be normalized
    """
    max_d = df[col].max()
    min_d = df[col].min()
    df[col] = (df[col] - min_d)/(max_d - min_d)

# %%
#Normalize allnumerical columns so that min value is 0 and max value is 1
num_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num = df.select_dtypes(include=num_types)
        
for col in num.columns:
    normalize_column(col)

# %% [markdown]
# ## Kmeans Clustering

# %%
km = KMeans(n_clusters=25)
pred = km.fit_predict(num)
df['pred'] = pred
normalize_column('pred')

# %%
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594   0.0      0.985944
# 1        0.9630   0.0      0.734940
# 2        0.0394   0.0      0.964859
# 3        0.1650   0.0      0.970884
# 4        0.2530   0.0      0.960843
# ...         ...   ...           ...
# 170648   0.6080   1.0      0.084940
# 170649   0.7340   1.0      0.206827
# 170650   0.6370   1.0      0.101406
# 170651   0.1950   1.0      0.010020
# 170652   0.6420   1.0      0.132530
#
#                                                   artists  danceability  \
# 0       Sergei Rachmaninoff, James Levine, Berliner Ph...      0.282389
# 1                                              Dennis Day      0.828947
# 2       KHP Kridhamardawa Karaton Ngayogyakarta Hadini...      0.331984
# 3                                            Frank Parker      0.278340
# 4                                              Phil Regan      0.423077
# ...                                                   ...           ...
# 170648   Anuel AA, Daddy Yankee, KAROL G, Ozuna, J Balvin      0.795547
# 170649                                           Ashnikko      0.725709
# 170650                                            MAMAMOO      0.641700
# 170651                                             Eminem      0.679150
# 170652                                    KEVVO, J Balvin      0.866397
#
#         energy  explicit  instrumentalness       key  liveness  loudness  \
# 0        0.211       0.0          0.878000  0.909091    0.6650  0.624916
# 1        0.341       0.0          0.000000  0.636364    0.1600  0.744797
# 2        0.166       0.0          0.913000  0.272727    0.1010  0.707071
# 3        0.309       0.0          0.000028  0.454545    0.3810  0.793736
# 4        0.193       0.0          0.000002  0.272727    0.2290  0.781521
# ...        ...       ...               ...       ...       ...       ...
# 170648   0.808       0.0          0.000289  0.636364    0.0822  0.881654
# 170649   0.753       0.0          0.000000  0.636364    0.1010  0.845353
# 170650   0.858       0.0          0.000009  0.363636    0.2580  0.904769
# 170651   0.623       1.0          0.000008  0.181818    0.6430  0.827484
# 170652   0.721       1.0          0.004710  0.636364    0.1820  0.862454
#
#         mode                                               name  popularity  \
# 0        1.0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...        0.04
# 1        1.0                            Clancy Lowered the Boom        0.05
# 2        1.0                                          Gati Bali        0.05
# 3        1.0                                          Danny Boy        0.03
# 4        1.0                        When Irish Eyes Are Smiling        0.02
# ...      ...                                                ...         ...
# 170648   1.0                                              China        0.72
# 170649   1.0                        Halloweenie III: Seven Days        0.68
# 170650   0.0                                                AYA        0.76
# 170651   1.0                                           Darkness        0.70
# 170652   1.0                    Billetes Azules (with J Balvin)        0.74
#
#         speechiness     tempo  duration_min Song Decade      pred
# 0          0.037732  0.332450      0.153051       1920s  0.458333
# 1          0.427835  0.250243      0.032455       1920s  0.458333
# 2          0.034948  0.453125      0.091586       1920s  0.875000
# 3          0.036495  0.411113      0.037902       1920s  0.000000
# 4          0.039175  0.417503      0.029899       1920s  0.000000
# ...             ...       ...           ...         ...       ...
# 170648     0.090825  0.431318      0.054907       2020s  0.208333
# 170649     0.062371  0.566456      0.026898       2020s  0.541667
# 170650     0.083402  0.376531      0.038124       2020s  0.208333
# 170651     0.317526  0.308225      0.061465       2020s  0.625000
# 170652     0.111340  0.390096      0.034122       2020s  0.208333
#
# [170088 rows x 19 columns]

# %%
df.drop(['Song Decade'],axis=1,inplace=True)

# %%
# class
class Song_Recommender:
    """
    Neighborhood-Based Collaborative Filtering Recommendation System
    using Manhattan Distance to find similar songs.
    """
    def __init__(self, data):
        self.data_ = data

    def get_recommendations(self, song_name, n_top):
        distances = []
        
        # Select numeric columns only
        numeric_cols = self.data_.select_dtypes(include=['number']).columns

        # Locate the given song
        song_row = self.data_[self.data_['name'].str.lower() == song_name.lower()]
        
        if song_row.empty:
            print(f"Warning: '{song_name}' not found in the dataset.")
            return None

        song = song_row.iloc[0]  # Extract first match
        
        # Remove the selected song from dataset
        rem_data = self.data_[self.data_['name'].str.lower() != song_name.lower()]
        
        for _, r_song in tqdm(rem_data.iterrows(), total=len(rem_data)):
            dist = np.abs(song[numeric_cols] - r_song[numeric_cols]).sum()  # Manhattan distance
            distances.append(dist)
        
        # Add distance column
        rem_data = rem_data.copy()
        rem_data['distance'] = distances
        
        # Sort by distance (ascending)
        rem_data = rem_data.sort_values('distance')

        # Return top recommendations
        return rem_data[['artists', 'name', 'distance']].head(n_top)

# %%
#Instanstiate the Recommender Class
recommender = Song_Recommender(df)
recommender.get_recommendations('Red Roses (feat. Landon Cube)', 5)
# Out:
# 100%|██████████| 170087/170087 [00:19<00:00, 8547.89it/s]
#                              artists  \
# 57027   Vince Staples, 6LACK, Mereba
# 56966              Maroon 5, Cardi B
# 38093                          Bazzi
# 38190              Maroon 5, Cardi B
# 170466           5 Seconds of Summer
#
#                                                  name  distance
# 57027   Yo Love - From "Queen & Slim: The Soundtrack"  0.448912
# 56966                  Girls Like You (feat. Cardi B)  0.585182
# 38093                                            3:15  0.591376
# 38190                  Girls Like You (feat. Cardi B)  0.595182
# 170466                                         Old Me  0.596551

# %%
recommender.get_recommendations('canon in d', 10)
# Out:
# 100%|██████████| 170083/170083 [00:19<00:00, 8542.30it/s]
#                                         artists  \
# 72203                             Patrick Doyle
# 72737                                   Grouper
# 105694  John Williams, Yo-Yo Ma, Itzhak Perlman
# 15914                              Yann Tiersen
# 121378                            John Williams
# 137065                             Squarepusher
# 72085                       Jean-Yves Thibaudet
# 168234                            Thad Fiscella
# 122483                               David Tolk
# 71443                  Mulgrew Miller, Wingspan
#
#                                                      name  distance
# 72203                                     Neville's Waltz  0.459931
# 72737                  Heavy Water/I'd Rather Be Sleeping  0.480263
# 105694                                     Sayuri's Theme  0.530977
# 15914               Comptine d'un autre été, l'après-midi  0.534069
# 121378                                Dobby the House Elf  0.554862
# 137065                                             Tommib  0.592818
# 72085   Arrival To Netherfield - From "Pride & Prejudi...  0.622038
# 168234                                           For Ross  0.623824
# 122483                                              Grace  0.633198
# 71443                            It Never Entered My Mind  0.643534

# %%
recommender.get_recommendations('dynamite', 10)
# Out:
# 100%|██████████| 170081/170081 [00:19<00:00, 8567.85it/s]
#                                                  artists  \
# 36728                                   Bowling For Soup
# 18017                                      One Direction
# 17225                                          Lady Gaga
# 54538                                       Billy Talent
# 18085  Victorious Cast, Victoria Justice, Elizabeth G...
# 18905                                         Little Mix
# 18192                                         Katy Perry
# 36515                                 Lady Gaga, Beyoncé
# 37542                                5 Seconds of Summer
# 17237                                         Katy Perry
#
#                            name  distance
# 36728               Stacy's Mom  0.222270
# 18017  What Makes You Beautiful  0.312001
# 17225                Poker Face  0.394117
# 54538             Fallen Leaves  0.437097
# 18085               Take A Hint  0.461421
# 18905        Shout Out to My Ex  0.461571
# 18192                Part Of Me  0.513080
# 36515                 Telephone  0.518168
# 37542           She's Kinda Hot  0.525262
# 17237           I Kissed A Girl  0.526919

# %%
recommender.get_recommendations('lovely', 10)
# Out:
# 100%|██████████| 170084/170084 [00:20<00:00, 8355.56it/s]
#                                       artists  \
# 124054                                SVRCINA
# 73378                           Michael Bublé
# 37077                           Michael Bublé
# 56328                  Troye Sivan, Alex Hope
# 55443                           Michael Bublé
# 56176   Enrique Iglesias, Marco Antonio Solís
# 106801                         Bunbury, Tulsa
# 169971                        Sabrina Claudio
# 73857                            Lana Del Rey
# 169557                           Lana Del Rey
#
#                                    name  distance
# 124054                      Battlefield  0.494993
# 73378   All I Want for Christmas Is You  0.524203
# 37077   All I Want for Christmas Is You  0.551910
# 56328                              BLUE  0.569630
# 55443   All I Want for Christmas Is You  0.572011
# 56176                       El Perdedor  0.594575
# 106801    Frente a frente (feat. Tulsa)  0.622344
# 169971                      Stand Still  0.640508
# 73857                 Money Power Glory  0.644740
# 169557                         Religion  0.698622

# %%
recommender.get_recommendations('lonely', 10)
# Out:
# 100%|██████████| 170071/170071 [00:20<00:00, 8441.47it/s]
#                            artists                                 name  \
# 16168                       Jaheim                 Put That Woman First
# 155318            Melanie Martinez                           Drama Club
# 73283                Amy Winehouse                            Half Time
# 56407                  Post Malone                             Up There
# 153225                     Molotov                      Gimme Tha Power
# 57273   YoungBoy Never Broke Again                         I Expect You
# 154848  YoungBoy Never Broke Again                          War with Us
# 16102                      Ashanti                                Happy
# 169952                Brent Faiyaz  First World Problemz / Nobody Carez
# 17520                   Mike Jones                          Next to You
#
#         distance
# 16168   0.519384
# 155318  0.618653
# 73283   0.730193
# 56407   0.740541
# 153225  0.752253
# 57273   0.772096
# 154848  0.778322
# 16102   0.792508
# 169952  0.793038
# 17520   0.803564

# %%
recommender.get_recommendations('senorita', 10)
# Out:
# 100%|██████████| 170087/170087 [00:20<00:00, 8462.59it/s]
#                                          artists  \
# 70253                            MC Lyte, Xscape
# 165639                     Mack 10, Ice Cube, WC
# 167129                                     JAE-P
# 167923  Calle 13, Bajofondo Tango Club, Panasuyo
# 151539                            Big L, Shyheim
# 88387                                   Jadakiss
# 105771           Common, John Legend, Kanye West
# 70617                  Missy Elliott, 702, Magoo
# 138093     Trick Daddy, Chamillionaire, Goldrush
# 70797                                        DMX
#
#                                                      name  distance
# 70253                  Keep On, Keepin' On (feat. Xscape)  0.485355
# 165639                            Westside Slaughterhouse  0.668707
# 167129                                      Perdóname Amá  0.676358
# 167923  Tango del Pecado (feat. Bajofondo Tango Club &...  0.694740
# 151539                                      Furious Anger  0.704040
# 88387                                  Knock Yourself Out  0.736672
# 105771                                           They Say  0.745865
# 70617                     Beep Me 911 (feat. 702 & Magoo)  0.752593
# 138093       Bet That (feat. Chamillionaire and GoldRush)  0.756799
# 70797                                       I Can Feel It  0.766257
